# %%
import sys
# !pip install kaggle
# Out:
# ...
#     100% |████████████████████████████████| 61kB 18.2MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 27.7MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 81kB 35.6MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for kaggle ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/57/4e/e8/bb28d035162fb8f17f8ca5d42c3230e284c6aa565b42b72674
#   Running setup.py bdist_wheel for python-slugify ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/11/94/81/312969455540cb0e6a773e5d68a73c14128bfdfd4a7969bb4f
# Successfully built kaggle python-slugify
# ...
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !rm -R ~/.kaggle
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json
# !echo "{\"username\":\"blainerothrock\",\"key\":\"da177fa7ba3ce8ddbc4d0c92496e99f3\"}" > /home/ec2-user/.kaggle/kaggle.json
# !chmod 600 /home/ec2-user/.kaggle/kaggle.json
# Out:
# rm: cannot remove ‘/home/ec2-user/.kaggle’: No such file or directory

# %%
# !kaggle competitions download -c airbus-ship-detection
# Out:
# ...
# 100%|█████████████████████████████████████▉| 28.6G/28.6G [10:02<00:00, 31.3MB/s]
# 100%|██████████████████████████████████████| 28.6G/28.6G [10:03<00:00, 50.9MB/s]

# %%
# !unzip airbus-ship-detection.zip
# Out:
# Archive:  airbus-ship-detection.zip
#   inflating: sample_submission_v2.csv
#   inflating: test_v2/00002bd58.jpg
#   inflating: test_v2/00015efb6.jpg
#   inflating: test_v2/00023d5fc.jpg
#   inflating: test_v2/000367c13.jpg
#   inflating: test_v2/0008ca6e9.jpg
#   inflating: test_v2/000a4635f.jpg
#   inflating: test_v2/000bd9dbf.jpg
#   inflating: test_v2/000f7d875.jpg
#   inflating: test_v2/0010551d9.jpg
#   inflating: test_v2/001839c6f.jpg
#   inflating: test_v2/002a943bf.jpg
#   inflating: test_v2/00313b166.jpg
#   inflating: test_v2/00327b02d.jpg
#   inflating: test_v2/0035268d9.jpg
#   inflating: test_v2/003b58a76.jpg
#   inflating: test_v2/0044e3dda.jpg
#   inflating: test_v2/0046967a4.jpg
#   inflating: test_v2/004751507.jpg
#   inflating: test_v2/0047c79fc.jpg
#   inflating: test_v2/004946ceb.jpg
#   inflating: test_v2/004dd347a.jpg
#   inflating: test_v2/00506a19e.jpg
#   inflating: test_v2/0057c059b.jpg
#   inflating: test_v2/005b8152d.jpg
# ...
